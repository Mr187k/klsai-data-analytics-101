# %%
pwd
# Out:
# 'C:\\Users\\Mr187\\Documents\\data_analytics_101\\da_101'

# %%
import pandas as pd
import numpy as np

# %%
exp = pd.read_csv ('C://Users//Mr187//Documents//data_analytics_101//da_101/55-malaysias-export-destination.csv', encoding ='iso8859-1', header=2,)

# %%
exp.head()
# Out:
#    Year  Month         Country Country Code Total Export (USD)
# 0  2016    1.0     AFGHANISTAN           AF          6,533,359
# 1  2016    1.0         ALBANIA           AL             95,077
# 2  2016    1.0         ALGERIA           DZ         11,758,400
# 3  2016    1.0  AMERICAN SAMOA           AS             39,681
# 4  2016    1.0         ANDORRA           AD             72,293

# %%
exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2573 entries, 0 to 2572
# Data columns (total 5 columns):
# Year                  2572 non-null object
# Month                 2571 non-null float64
# Country               2571 non-null object
# Country Code          2559 non-null object
# Total Export (USD)    2571 non-null object
# dtypes: float64(1), object(4)
# memory usage: 100.6+ KB

# %%
exp[exp.isnull().values.any(axis=1)]
# Out:
#                                                    Year  Month Country  \
# 2571                                                NaN    NaN     NaN
# 2572  Note:\ni. Source : Department Of Statistics Ma...    NaN     NaN
#
#      Country Code Export
# 2571          NaN    NaN
# 2572          NaN    NaN

# %%
list(exp)
# Out:
# ['Year', 'Month', 'Country', 'Country Code', 'Export']

# %%
# rename columns
exp.columns = ['Year', 'Month', 'Country', 'Country Code', 'Export']
# replace \xa0
exp = exp.replace({'\xa0':" "}, regex=True)
# palcing NAM instead of NA
exp.loc[exp['Country'] == "NAMIBIA", 'Country Code'] = "NAM"
# convert strings into number 
exp["Export"] = exp['Export'].replace({',':''}, regex=True)
exp["Export"] = exp['Export'].apply(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-0f793b4e7c48> in <module>
#       7 # convert strings into number
#       8 exp["Export"] = exp['Export'].replace({',':''}, regex=True)
# ----> 9 exp["Export"] = exp['Export'].apply(int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# ValueError: cannot convert float NaN to integer

# %%
type(exp['Total\xa0Export (USD)'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total\xa0Export (USD)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-5c54d1c4f612> in <module>
# ----> 1 type(exp['Total\xa0Export (USD)'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total\xa0Export (USD)'

# %%
list(exp)
# Out:
# ['Year', 'Month', 'Country', 'Country Code', 'Export']

# %%
exp[exp.isnull().values.any(axis=1)]
# Out:
#                                                    Year  Month Country  \
# 2571                                                NaN    NaN     NaN
# 2572  Note:\ni. Source : Department Of Statistics Ma...    NaN     NaN
#
#      Country Code Export
# 2571          NaN    NaN
# 2572          NaN    NaN

# %%
exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2573 entries, 0 to 2572
# Data columns (total 5 columns):
# Year            2572 non-null object
# Month           2571 non-null float64
# Country         2571 non-null object
# Country Code    2571 non-null object
# Export          2571 non-null object
# dtypes: float64(1), object(4)
# memory usage: 100.6+ KB

# %%
col_exp = ['Month', 'Country', 'Export']

# %%
slim_exp = exp[col_exp]

# %%
slim_exp
# Out:
#       Month                   Country      Export
# 0       1.0               AFGHANISTAN     6533359
# 1       1.0                   ALBANIA       95077
# 2       1.0                   ALGERIA    11758400
# 3       1.0            AMERICAN SAMOA       39681
# 4       1.0                   ANDORRA       72293
# 5       1.0                    ANGOLA     8731875
# 6       1.0                  ANGUILLA        4578
