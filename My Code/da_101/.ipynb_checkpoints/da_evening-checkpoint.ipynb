# %%
pwd
# Out:
# 'C:\\Users\\Mr187\\Documents\\data_analytics_101\\da_101'

# %%
import pandas as pd
import numpy as np

# %%
imp = pd.read_csv ('C:\\Users\\Mr187\\Documents\\data_analytics_101\\da_101\\56-malaysias-import-sources.csv', encoding ='iso8859-1', header=2,)

# %%
imp.head()
# Out:
#    Year  Month         Country Country Code Total Import (USD)
# 0  2016    1.0     AFGHANISTAN           AF             10,609
# 1  2016    1.0         ALBANIA           AL              7,947
# 2  2016    1.0         ALGERIA           DZ                  0
# 3  2016    1.0  AMERICAN SAMOA           AS                  0
# 4  2016    1.0         ANDORRA           AD                  0

# %%
imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2573 entries, 0 to 2572
# Data columns (total 5 columns):
# Year                  2572 non-null object
# Month                 2571 non-null float64
# Country               2571 non-null object
# Country Code          2559 non-null object
# Total Import (USD)    2571 non-null object
# dtypes: float64(1), object(4)
# memory usage: 100.6+ KB

# %%
imp.isnull()
# Out:
#        Year  Month  Country  Country Code  Total Import (USD)
# 0     False  False    False         False               False
# 1     False  False    False         False               False
# 2     False  False    False         False               False
# 3     False  False    False         False               False
# 4     False  False    False         False               False
# 5     False  False    False         False               False
# 6     False  False    False         False               False
# 7     False  False    False         False               False
# 8     False  False    False         False               False
# 9     False  False    False         False               False
# 10    False  False    False         False               False
# 11    False  False    False         False               False
# 12    False  False    False         False               False
# 13    False  False    False         False               False
# ...

# %%
imp.isnull().values.any()
# Out:
# True

# %%
imp[imp.isnull().values.any(axis=1)]
# Out:
#                                                    Year  Month  Country  \
# 125                                                2016    1.0  NAMIBIA
# 339                                                2016    2.0  NAMIBIA
# 557                                                2016    3.0  NAMIBIA
# 772                                                2016    4.0  NAMIBIA
# 991                                                2016    5.0  NAMIBIA
# 1206                                               2016    6.0  NAMIBIA
# 1421                                               2016    7.0  NAMIBIA
# 1632                                               2016    8.0  NAMIBIA
# 1845                                               2016    9.0  NAMIBIA
# 2059                                               2016   10.0  NAMIBIA
# 2274                                               2016   11.0  NAMIBIA
# 2488                                               2016   12.0  NAMIBIA
# ...

# %%
list(imp)
# Out:
# ['Year', 'Month', 'Country', 'Country\xa0Code', 'Total\xa0Import (USD)']

# %%
imp['Total\xa0Import (USD)'][0]
# Out:
# '10,609'

# %%
type(imp['Total\xa0Import (USD)'])
# Out:
# pandas.core.series.Series

# %%
#rename columns
imp.columns = ['Year', 'Month', 'Country', 'Country Code', 'Import']

# %%
list(imp)
# Out:
# ['Year', 'Month', 'Country', 'Country Code', 'Import']

# %%
#replace
# replace \xa0
imp = imp.replace({'\xa0':" "}, regex=True)
# palcing NAM instead of NA
imp.loc[imp['Country'] == "NAMIBIA", 'Country Code'] = "NAM"
# convert strings into number

# %%
imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2573 entries, 0 to 2572
# Data columns (total 5 columns):
# Year            2572 non-null object
# Month           2571 non-null float64
# Country         2571 non-null object
# Country Code    2571 non-null object
# Import          2571 non-null object
# dtypes: float64(1), object(4)
# memory usage: 100.6+ KB

# %%
col_imp = ['Import']

# %%
col_imp
# Out:
# ['Import']

# %%
slim_imp = imp[col_imp]

# %%
slim_imp.head(20)
# Out:
#          Import
# 0        10,609
# 1         7,947
# 2             0
# 3             0
# 4             0
# 5       290,967
# 6             0
# 7             0
# 8    43,458,878
# 9             0
# 10            0
# 11  289,092,801
# 12   44,902,463
# 13            0
# 14        8,385
# 15    3,124,641
# 16   13,382,659
# 17        2,797
# 18    2,073,899
# 19   45,226,976

# %%
#Open Exportdataset and add

# %%
exp = pd.read_csv ('C://Users//Mr187//Documents//data_analytics_101//da_101/55-malaysias-export-destination.csv', encoding ='iso8859-1', header=2, skipfooter=2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
exp.head()
# Out:
#    Year  Month         Country Country Code Total Export (USD)
# 0  2016      1     AFGHANISTAN           AF          6,533,359
# 1  2016      1         ALBANIA           AL             95,077
# 2  2016      1         ALGERIA           DZ         11,758,400
# 3  2016      1  AMERICAN SAMOA           AS             39,681
# 4  2016      1         ANDORRA           AD             72,293

# %%
exp[exp.isnull().values.any(axis=1)]
# Out:
#       Year  Month  Country Country Code Total Export (USD)
# 125   2016      1  NAMIBIA          NaN             92,303
# 339   2016      2  NAMIBIA          NaN          1,053,876
# 557   2016      3  NAMIBIA          NaN            479,729
# 772   2016      4  NAMIBIA          NaN            189,471
# 991   2016      5  NAMIBIA          NaN            258,658
# 1206  2016      6  NAMIBIA          NaN            654,832
# 1421  2016      7  NAMIBIA          NaN            172,759
# 1632  2016      8  NAMIBIA          NaN            334,900
# 1845  2016      9  NAMIBIA          NaN            634,898
# 2059  2016     10  NAMIBIA          NaN            264,015
# 2274  2016     11  NAMIBIA          NaN            132,248
# 2488  2016     12  NAMIBIA          NaN            300,347

# %%
list(exp)
# Out:
# ['Year', 'Month', 'Country', 'Country Code', 'Export']

# %%
# rename columns
exp.columns = ['Year', 'Month', 'Country', 'Country Code', 'Export']
# replace \xa0
exp = exp.replace({'\xa0':" "}, regex=True)
# palcing NAM instead of NA
exp.loc[exp['Country'] == "NAMIBIA", 'Country Code'] = "NAM"
# convert strings into number 
exp["Export"] = exp['Export'].replace({',':''}, regex=True)
exp["Export"] = exp['Export'].apply(int)

# %%
type(exp['Total\xa0Export (USD)'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total\xa0Export (USD)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-138-5c54d1c4f612> in <module>
# ...

# %%
list(exp)
# Out:
# ['Year', 'Month', 'Country', 'Country Code', 'Export']

# %%
col_exp = ['Month', 'Country', 'Export']

# %%
slim_exp = exp[col_exp]

# %%
slim_exp
# Out:
#       Month                   Country      Export
# 0         1               AFGHANISTAN     6533359
# 1         1                   ALBANIA       95077
# 2         1                   ALGERIA    11758400
# 3         1            AMERICAN SAMOA       39681
# 4         1                   ANDORRA       72293
# 5         1                    ANGOLA     8731875
# 6         1                  ANGUILLA        4578
# 7         1         ANTIGUA & BARBUDA      399412
# 8         1                 ARGENTINA    12524335
# 9         1                   ARMENIA      195464
# 10        1                     ARUBA       26220
# 11        1                 AUSTRALIA   500157200
# 12        1                   AUSTRIA     9958516
# 13        1                AZERBAIJAN     1812406
# 14        1                   BAHAMAS      254562
# 15        1                   BAHRAIN     4144108
# 16        1                BANGLADESH    79600614
# 17        1                  BARBADOS      107154
# ...

# %%
slim_imp.head(10)
# Out:
#        Import
# 0      10,609
# 1       7,947
# 2           0
# 3           0
# 4           0
# 5     290,967
# 6           0
# 7           0
# 8  43,458,878
# 9           0

# %%
slim_exp.head(10)
# Out:
#    Month            Country    Export
# 0      1        AFGHANISTAN   6533359
# 1      1            ALBANIA     95077
# 2      1            ALGERIA  11758400
# 3      1     AMERICAN SAMOA     39681
# 4      1            ANDORRA     72293
# 5      1             ANGOLA   8731875
# 6      1           ANGUILLA      4578
# 7      1  ANTIGUA & BARBUDA    399412
# 8      1          ARGENTINA  12524335
# 9      1            ARMENIA    195464

# %%
slim_exp.tail(10)
# Out:
#       Month                   Country      Export
# 2561     12            UNITED KINGDOM   169513157
# 2562     12   UNITED REP. OF TANZANIA     8936966
# 2563     12  UNITED STATES OF AMERICA  1608469709
# 2564     12                   URUGUAY     2063973
# 2565     12                UZBEKISTAN     4375202
# 2566     12                   VANUATU      324606
# 2567     12                 VENEZUELA      470352
# 2568     12             WESTERN SAMOA      319444
# 2569     12                    ZAMBIA      271947
# 2570     12                  ZIMBABWE      619407

# %%
slim_imp.tail(10)
# Out:
#              Import
# 2563  1,157,759,666
# 2564        867,593
# 2565            360
# 2566        307,618
# 2567     22,124,814
# 2568              0
# 2569        862,212
# 2570        143,476
# 2571            NaN
# 2572            NaN

# %%
exp_imp = pd.merge(slim_exp, slim_imp, how = "inner", left_index= True, right_index=True)

# %%
#exp_imp['BOT'] = int(exp_imp['Export']) - int(exp_imp["Import"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-9ad27d43f732> in <module>
# ----> 1 exp_imp['BOT'] = int(exp_imp['Export']) - int(exp_imp["Import"])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     116             return converter(self.iloc[0])
#     117         raise TypeError("cannot convert the series to "
# --> 118                         "{0}".format(str(converter)))
#     119
#     120     return wrapper
#
# TypeError: cannot convert the series to <class 'int'>

# %%
exp_imp(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-147-48def62dd84e> in <module>
# ----> 1 exp_imp(10)
#
# TypeError: 'DataFrame' object is not callable

# %%
exp_imp.tail(50)
# Out:
#       Month                     Country      Export         Import
# 2521     12           REPUBLIC OF YEMEN    18236489      1,059,735
# 2522     12             REUNION ISLANDS     1361794         16,970
# 2523     12                     ROMANIA     6619859      2,351,855
# 2524     12          RUSSIAN FEDERATION    49966367     36,820,914
# 2525     12                      RWANDA      213650      2,094,047
# 2526     12                 SAINT LUCIA      181060              0
# 2527     12    SAINT VINCENT/GRENADINES       13151              0
# 2528     12                SAUDI ARABIA    81056904    286,006,328
# 2529     12                     SENEGAL     6312979         16,232
# 2530     12                      SERBIA      722600        126,162
# 2531     12                  SEYCHELLES     9767468        705,207
# 2532     12                SIERRA LEONE     1967865              0
# 2533     12                    SLOVAKIA     3576233      2,180,540
# ...

# %%
exp_imp.tail(50)
# Out:
#       Month                     Country      Export         Import
# 2523   12.0                     ROMANIA     6619859      2,351,855
# 2524   12.0          RUSSIAN FEDERATION    49966367     36,820,914
# 2525   12.0                      RWANDA      213650      2,094,047
# 2526   12.0                 SAINT LUCIA      181060              0
# 2527   12.0    SAINT VINCENT/GRENADINES       13151              0
# 2528   12.0                SAUDI ARABIA    81056904    286,006,328
# 2529   12.0                     SENEGAL     6312979         16,232
# 2530   12.0                      SERBIA      722600        126,162
# 2531   12.0                  SEYCHELLES     9767468        705,207
# 2532   12.0                SIERRA LEONE     1967865              0
# 2533   12.0                    SLOVAKIA     3576233      2,180,540
# 2534   12.0                    SLOVENIA    13351207      1,333,865
# 2535   12.0  SOCIALIST REP. OF VIET NAM   481624435    469,874,903
# ...

# %%
exp_imp["Import"]
# Out:
# 0              10,609
# 1               7,947
# 2                   0
# 3                   0
# 4                   0
# 5             290,967
# 6                   0
# 7                   0
# 8          43,458,878
# 9                   0
# 10                  0
# 11        289,092,801
# 12         44,902,463
# 13                  0
# 14              8,385
# 15          3,124,641
# 16         13,382,659
# 17              2,797
# 18          2,073,899
# 19         45,226,976
# 20                  0
# 21              6,917
# 22                  0
# 23                  0
# 24          1,190,716
# 25                277
# 26              2,178
# 27        223,793,600
# 28             95,994
# 29          2,199,608
#             ...
# 2543       42,101,625
# 2544      203,203,528
# 2545          115,424
# 2546      895,242,239
# 2547                0
# 2548      891,116,697
# 2549           28,180
# 2550                0
# 2551                0
# 2552           10,243
# ...

# %%
exp_imp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2573 entries, 0 to 2572
# Data columns (total 4 columns):
# Month      2571 non-null float64
# Country    2571 non-null object
# Export     2571 non-null object
# Import     2571 non-null object
# dtypes: float64(1), object(3)
# memory usage: 80.5+ KB

# %%
exp_imp.dtypes
# Out:
# Month      float64
# Country     object
# Export      object
# Import      object
# dtype: object

# %%
# replace \xa0
exp_imp = exp_imp.replace({',':""}, regex=True)

# %%
exp_imp['BOT'] = int(exp_imp['Export']) - int(exp_imp["Import"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-9ad27d43f732> in <module>
# ----> 1 exp_imp['BOT'] = int(exp_imp['Export']) - int(exp_imp["Import"])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     116             return converter(self.iloc[0])
#     117         raise TypeError("cannot convert the series to "
# --> 118                         "{0}".format(str(converter)))
#     119
#     120     return wrapper
#
# TypeError: cannot convert the series to <class 'int'>

# %%
exp_imp = exp_imp['Import'].astype(str).astype(int)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-111-d9738d750187> in <module>
# ----> 1 exp_imp = exp_imp['Import'].astype(str).astype(int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
# ...

# %%
exp_imp.Import
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-e41164403e55> in <module>
# ----> 1 exp_imp.Import
#
# AttributeError: 'str' object has no attribute 'Import'

# %%
exp_imp.dtypes
# Out:
# Month      float64
# Country     object
# Export      object
# Import      object
# dtype: object

# %%
exp_imp['Export'] = exp['Export'].apply(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-af0d6578c784> in <module>
# ----> 1 exp_imp['Export'] = exp['Export'].apply(int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# ValueError: cannot convert float NaN to integer

# %%
exp_imp.head(10)
# Out:
#    Month            Country    Export    Import
# 0    1.0        AFGHANISTAN   6533359     10609
# 1    1.0            ALBANIA     95077      7947
# 2    1.0            ALGERIA  11758400         0
# 3    1.0     AMERICAN SAMOA     39681         0
# 4    1.0            ANDORRA     72293         0
# 5    1.0             ANGOLA   8731875    290967
# 6    1.0           ANGUILLA      4578         0
# 7    1.0  ANTIGUA & BARBUDA    399412         0
# 8    1.0          ARGENTINA  12524335  43458878
# 9    1.0            ARMENIA    195464         0

# %%
slim_imp['Import'] = exp['Import'].apply(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Import'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-7217f2310e52> in <module>
# ...

# %%
slim_exp.tail(10)
# Out:
#       Month                   Country      Export
# 2563   12.0  UNITED STATES OF AMERICA  1608469709
# 2564   12.0                   URUGUAY     2063973
# 2565   12.0                UZBEKISTAN     4375202
# 2566   12.0                   VANUATU      324606
# 2567   12.0                 VENEZUELA      470352
# 2568   12.0             WESTERN SAMOA      319444
# 2569   12.0                    ZAMBIA      271947
# 2570   12.0                  ZIMBABWE      619407
# 2571    NaN                       NaN         NaN
# 2572    NaN                       NaN         NaN

# %%
# Out:
#       Month                   Country      Export      Import
# 2563   12.0  UNITED STATES OF AMERICA  1608469709  1157759666
# 2564   12.0                   URUGUAY     2063973      867593
# 2565   12.0                UZBEKISTAN     4375202         360
# 2566   12.0                   VANUATU      324606      307618
# 2567   12.0                 VENEZUELA      470352    22124814
# 2568   12.0             WESTERN SAMOA      319444           0
# 2569   12.0                    ZAMBIA      271947      862212
# 2570   12.0                  ZIMBABWE      619407      143476
# 2571    NaN                       NaN         NaN         NaN
# 2572    NaN                       NaN         NaN         NaN

# %%
exp_imp.drop(exp_imp.tail(2).index,inplace=True)

# %%
exp_imp.tail(10)
# Out:
#       Month                   Country      Export      Import
# 2561   12.0            UNITED KINGDOM   169513157   136487520
# 2562   12.0   UNITED REP. OF TANZANIA     8936966     3550002
# 2563   12.0  UNITED STATES OF AMERICA  1608469709  1157759666
# 2564   12.0                   URUGUAY     2063973      867593
# 2565   12.0                UZBEKISTAN     4375202         360
# 2566   12.0                   VANUATU      324606      307618
# 2567   12.0                 VENEZUELA      470352    22124814
# 2568   12.0             WESTERN SAMOA      319444           0
# 2569   12.0                    ZAMBIA      271947      862212
# 2570   12.0                  ZIMBABWE      619407      143476

# %%
exp_imp['Export'] = exp['Export'].apply(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-af0d6578c784> in <module>
# ----> 1 exp_imp['Export'] = exp['Export'].apply(int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# ValueError: cannot convert float NaN to integer
